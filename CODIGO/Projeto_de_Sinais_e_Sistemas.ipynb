# %% [markdown]
# <a href="https://colab.research.google.com/github/aasb2/Projeto-de-Sinais-e-Sistemas/blob/main/CODIGO/Projeto_de_Sinais_e_Sistemas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as urlib2
from matplotlib.image import imread
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from scipy.fftpack import dct,idct

# %%
def DCT(img):
  return dct(dct(img, norm = 'ortho'), norm = 'ortho')

def IDCT(img):
  return idct(idct(idct(img),norm = 'ortho'), norm = 'ortho')

# %%
link = "https://raw.githubusercontent.com/aasb2/Projeto-de-Sinais-e-Sistemas/main/BANCO-DE-IMAGENS/face.png"
img = imread(urlib2.urlopen(link) )
#plt.gray()
imgG = np.mean(img,-1)
imgT = DCT(imgG)
plt.imshow(img)

# %%
plt.imshow(imgG)

# %%
plt.imshow(imgT)

# %%
plt.imshow(IDCT(imgT))
